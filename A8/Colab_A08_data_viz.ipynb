# %% [markdown]
# # Data Visualization exercise

# %%
# importing the package(s) we want to use
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
### The input file is tab-delimited
tsv_Filepath = "https://raw.githubusercontent.com/csbfx/advpy122-data/master/euk.tsv"
# we can specify the delimiter by using the sep keyword argument
euk = pd.read_csv(tsv_Filepath, sep='\t')

# %%
### Using .head() and .tail() to see data content
euk.head()
# Out:
#                       Species   Kingdom           Class  Size (Mb)      GC%  \
# 0  Emiliania huxleyi CCMP1516  Protists  Other Protists    167.676     64.5
# 1        Arabidopsis thaliana    Plants     Land Plants    119.669  36.0529
# 2                 Glycine max    Plants     Land Plants    979.046  35.1153
# 3         Medicago truncatula    Plants     Land Plants    412.924   34.047
# 4        Solanum lycopersicum    Plants     Land Plants    828.349  35.6991
#
#   Number of genes Number of proteins  Publication year Assembly status
# 0           38549              38554              2013        Scaffold
# 1           38311              48265              2001      Chromosome
# 2           59847              71219              2010      Chromosome
# 3           37603              41939              2011      Chromosome
# 4           31200              37660              2010      Chromosome

# %%
euk.tail()
# Out:
#                        Species Kingdom        Class  Size (Mb)      GC%  \
# 8297  Saccharomyces cerevisiae   Fungi  Ascomycetes   3.993920     38.2
# 8298  Saccharomyces cerevisiae   Fungi  Ascomycetes   0.586761  38.5921
# 8299  Saccharomyces cerevisiae   Fungi  Ascomycetes  12.020400  38.2971
# 8300  Saccharomyces cerevisiae   Fungi  Ascomycetes  11.960900  38.2413
# 8301  Saccharomyces cerevisiae   Fungi  Ascomycetes  11.820700  38.2536
#
#      Number of genes Number of proteins  Publication year Assembly status
# 8297               -                  -              2017        Scaffold
# 8298             155                298              1992      Chromosome
# 8299               -                  -              2018      Chromosome
# 8300               -                  -              2018      Chromosome
# 8301               -                  -              2018      Chromosome

# %%
### .info() to provide information on the data
euk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8302 entries, 0 to 8301
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Species             8302 non-null   object
#  1   Kingdom             8302 non-null   object
#  2   Class               8302 non-null   object
#  3   Size (Mb)           8302 non-null   float64
#  4   GC%                 8302 non-null   object
#  5   Number of genes     8302 non-null   object
#  6   Number of proteins  8302 non-null   object
#  7   Publication year    8302 non-null   int64
#  8   Assembly status     8302 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 583.9+ KB

# %%
### What to do with '-' values?
## Change "-" into NAs
euk = pd.read_csv(tsv_Filepath, sep="\t", na_values=["-"])
euk
# Out:
#                          Species   Kingdom           Class   Size (Mb)  \
# 0     Emiliania huxleyi CCMP1516  Protists  Other Protists  167.676000
# 1           Arabidopsis thaliana    Plants     Land Plants  119.669000
# 2                    Glycine max    Plants     Land Plants  979.046000
# 3            Medicago truncatula    Plants     Land Plants  412.924000
# 4           Solanum lycopersicum    Plants     Land Plants  828.349000
# ...                          ...       ...             ...         ...
# 8297    Saccharomyces cerevisiae     Fungi     Ascomycetes    3.993920
# 8298    Saccharomyces cerevisiae     Fungi     Ascomycetes    0.586761
# 8299    Saccharomyces cerevisiae     Fungi     Ascomycetes   12.020400
# 8300    Saccharomyces cerevisiae     Fungi     Ascomycetes   11.960900
# 8301    Saccharomyces cerevisiae     Fungi     Ascomycetes   11.820700
#
#           GC%  Number of genes  Number of proteins  Publication year  \
# 0     64.5000          38549.0             38554.0              2013
# 1     36.0529          38311.0             48265.0              2001
# 2     35.1153          59847.0             71219.0              2010
# 3     34.0470          37603.0             41939.0              2011
# 4     35.6991          31200.0             37660.0              2010
# ...       ...              ...                 ...               ...
# 8297  38.2000              NaN                 NaN              2017
# 8298  38.5921            155.0               298.0              1992
# 8299  38.2971              NaN                 NaN              2018
# 8300  38.2413              NaN                 NaN              2018
# 8301  38.2536              NaN                 NaN              2018
#
#      Assembly status
# 0           Scaffold
# 1         Chromosome
# 2         Chromosome
# 3         Chromosome
# 4         Chromosome
# ...              ...
# 8297        Scaffold
# 8298      Chromosome
# 8299      Chromosome
# 8300      Chromosome
# 8301      Chromosome
#
# [8302 rows x 9 columns]

# %% [markdown]
# ## Visualize the relationship between two variables
#
# Can you see the relationship between genome size and the number of genes?

# %% [markdown]
# It is hard for us to see patterns by reading large tables of data. For example, look at the following table that contains the genome size and the number of genes for reptiles. Can you see the relationship between genome size and the number of genes?

# %%
## Look only look at reptile data using class 'Reptiles'
reptile_euk = euk[euk['Class'] == 'Reptiles']
reptile_euk[["Species","Class","Size (Mb)","Number of genes"]]
# Out:
#                            Species     Class  Size (Mb)  Number of genes
# 282            Anolis carolinensis  Reptiles    1799.14          22092.0
# 543            Sphenodon punctatus  Reptiles    4272.21              NaN
# 565               Pogona vitticeps  Reptiles    1716.68          21445.0
# 589      Platysternon megacephalum  Reptiles    2319.09              NaN
# 612               Podarcis muralis  Reptiles    1511.00              NaN
# 650              Cuora amboinensis  Reptiles    2214.83              NaN
# 730             Ophiophagus hannah  Reptiles    1594.07              NaN
# 944         Chrysemys picta bellii  Reptiles    2365.77          25289.0
# 1122                Chelonia mydas  Reptiles    2208.41          22336.0
# 1136    Alligator mississippiensis  Reptiles    2161.73          25012.0
# 1150            Crocodylus porosus  Reptiles    2049.54          19551.0
# 1218             Notechis scutatus  Reptiles    1665.53          22413.0
# 1224            Vipera berus berus  Reptiles    1532.39              NaN
# 1248           Pelodiscus sinensis  Reptiles    2202.48          24516.0
# 1294             Apalone spinifera  Reptiles    1931.08              NaN
# 1372             Crotalus horridus  Reptiles    1520.33              NaN
# 1376           Thamnophis sirtalis  Reptiles    1424.90          20101.0
# 1513             Python bivittatus  Reptiles    1435.05          21877.0
# 1526  Protobothrops mucrosquamatus  Reptiles    1673.88          21073.0
# 1576            Alligator sinensis  Reptiles    2270.57          24320.0
# 2135         Pantherophis guttatus  Reptiles    1404.22              NaN
# 2142               Gekko japonicus  Reptiles    2490.27          21197.0
# 2175               Paroedura picta  Reptiles    1694.16              NaN
# 2186             Lacerta bilineata  Reptiles    1418.15              NaN
# 2425    Protobothrops flavoviridis  Reptiles    1413.20              NaN
# 2519  Malaclemys terrapin terrapin  Reptiles    2439.75             13.0
# 2808              Crotalus pyrrhus  Reptiles    1126.79              NaN
# 3463      Crotalus viridis viridis  Reptiles    1340.20              NaN
# 3487           Pseudonaja textilis  Reptiles    1590.04          22151.0
# 3495             Salvator merianae  Reptiles    2068.17              NaN
# 3496        Chelonoidis abingdonii  Reptiles    2300.75              NaN
# 3747                 Cuora mccordi  Reptiles    2390.37              NaN
# 3810        Hydrophis cyanocinctus  Reptiles    1389.86              NaN
# 3811          Hydrophis hardwickii  Reptiles    1296.39              NaN
# 4556            Crocodylus porosus  Reptiles    2120.57              NaN
# 4561    Alligator mississippiensis  Reptiles    2161.71              NaN
# 5274    Alligator mississippiensis  Reptiles    2156.98              NaN

# %% [markdown]
# ### Use `relplot` to look at relationships
# We will use the `relplot` function, and the names of the columns that we want on the `X` and `Y` axes to look at the relationship between genome size and number of genes in Reptiles

# %%
### Relationship plot between genome size and number of genes in Retiles
reptile_size_num = sns.relplot(x="Size (Mb)", y="Number of genes", data=reptile_euk_small)
plt.title("Genome size and number of genes for reptiles", pad=10);

# %% [markdown]
# ### Can you create a new column to look at gene density?
# gene density = Number of genes / Size (Mb)

# %%
### Your Code
# gene density = Number of genes / Size (Mb)
# create the new column

reptile_euk_small["Gene density"] = reptile_euk_small["Number of genes"] / reptile_euk_small["Size (Mb)"]
reptile_euk_small[["Species","Class","Size (Mb)","Number of genes","Gene density"]]
# Out:
# <ipython-input-76-b57982a0e9fa>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reptile_euk_small["Gene density"] = reptile_euk_small["Number of genes"] / reptile_euk_small["Size (Mb)"]
#                            Species     Class  Size (Mb)  Number of genes  \
# 282            Anolis carolinensis  Reptiles    1799.14          22092.0
# 565               Pogona vitticeps  Reptiles    1716.68          21445.0
# 589      Platysternon megacephalum  Reptiles    2319.09              NaN
# 612               Podarcis muralis  Reptiles    1511.00              NaN
# 650              Cuora amboinensis  Reptiles    2214.83              NaN
# 730             Ophiophagus hannah  Reptiles    1594.07              NaN
# 944         Chrysemys picta bellii  Reptiles    2365.77          25289.0
# 1122                Chelonia mydas  Reptiles    2208.41          22336.0
# 1136    Alligator mississippiensis  Reptiles    2161.73          25012.0
# 1150            Crocodylus porosus  Reptiles    2049.54          19551.0
# 1218             Notechis scutatus  Reptiles    1665.53          22413.0
# 1224            Vipera berus berus  Reptiles    1532.39              NaN
# 1248           Pelodiscus sinensis  Reptiles    2202.48          24516.0
# 1294             Apalone spinifera  Reptiles    1931.08              NaN
# 1372             Crotalus horridus  Reptiles    1520.33              NaN
# 1376           Thamnophis sirtalis  Reptiles    1424.90          20101.0
# 1513             Python bivittatus  Reptiles    1435.05          21877.0
# 1526  Protobothrops mucrosquamatus  Reptiles    1673.88          21073.0
# 1576            Alligator sinensis  Reptiles    2270.57          24320.0
# 2135         Pantherophis guttatus  Reptiles    1404.22              NaN
# 2142               Gekko japonicus  Reptiles    2490.27          21197.0
# 2175               Paroedura picta  Reptiles    1694.16              NaN
# 2186             Lacerta bilineata  Reptiles    1418.15              NaN
# 2425    Protobothrops flavoviridis  Reptiles    1413.20              NaN
# 2519  Malaclemys terrapin terrapin  Reptiles    2439.75             13.0
# 2808              Crotalus pyrrhus  Reptiles    1126.79              NaN
# 2830            Thermophis baileyi  Reptiles    1747.68              NaN
# 3021            Gopherus agassizii  Reptiles    2184.97              NaN
# 3054  Terrapene mexicana triunguis  Reptiles    2571.27          24657.0
# 3239               Lacerta viridis  Reptiles    1439.84              NaN
# 3463      Crotalus viridis viridis  Reptiles    1340.20              NaN
# 3487           Pseudonaja textilis  Reptiles    1590.04          22151.0
# 3495             Salvator merianae  Reptiles    2068.17              NaN
# 3496        Chelonoidis abingdonii  Reptiles    2300.75              NaN
# 3747                 Cuora mccordi  Reptiles    2390.37              NaN
# 3810        Hydrophis cyanocinctus  Reptiles    1389.86              NaN
# 3811          Hydrophis hardwickii  Reptiles    1296.39              NaN
# 4556            Crocodylus porosus  Reptiles    2120.57              NaN
# 4561    Alligator mississippiensis  Reptiles    2161.71              NaN
# 5274    Alligator mississippiensis  Reptiles    2156.98              NaN
#
#       Gene density
# 282      12.279200
# 565      12.492136
# 589            NaN
# 612            NaN
# 650            NaN
# 730            NaN
# 944      10.689543
# 1122     10.114064
# 1136     11.570363
# 1150      9.539214
# 1218     13.456978
# 1224           NaN
# 1248     11.131089
# 1294           NaN
# 1372           NaN
# 1376     14.106955
# 1513     15.244765
# 1526     12.589313
# 1576     10.710967
# 2135           NaN
# 2142      8.511928
# 2175           NaN
# 2186           NaN
# 2425           NaN
# 2519      0.005328
# 2808           NaN
# 2830           NaN
# 3021           NaN
# 3054      9.589425
# 3239           NaN
# 3463           NaN
# 3487     13.931096
# 3495           NaN
# 3496           NaN
# 3747           NaN
# 3810           NaN
# 3811           NaN
# 4556           NaN
# 4561           NaN
# 5274           NaN

# %%
### Create the plot that represents the relation between Size (Mb) and density
# Is it what you expected?
reptile_size_density = sns.relplot(x="Size (Mb)", y="Gene density", data=reptile_euk_small)
plt.title("Genome size and gene density for reptiles", pad=10);

# %% [markdown]
# ## Seaborn
# These are other `kind` plots that we did not try in lectures. Look up seaborn documentation and try to create these new plots.
#
# 1.   Create a violin plot for genome size distribution against Class Land Plants.
# 2.   Create a scatter plot showing the relationship between Kingdom and Publication year
# 3. Create a bar plot for GC% for each Kingdom

# %%
### Your code - Create a violin plot for genome size distribution against Class Land Plants.
land_plants_class = euk[euk['Class'] == 'Land Plants']
land_plants_size = sns.violinplot(x="Class", y="Size (Mb)", data=land_plants_class)
plt.title("Genome size distribution against Land Plants");

# %%
### Your code - Create a scatter plot showing the relationship between Kingdom and Publication year
sns.relplot(x="Publication year", y="Kingdom", data=euk)
plt.title("Relationship between Kingdom and Publication year", pad=10);

# %%
### Your code - Create a bar plot for GC% for each Kingdom
sns.catplot(x="Kingdom", y="GC%", data=euk, kind="bar")
plt.title("GC% for each Kingdom", pad=10);
